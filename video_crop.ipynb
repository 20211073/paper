# %%
import cv2
import os
import numpy as np
import shutil

# %%
image_root = 'C:/Users/glad/Desktop/graduate_code/real_data_raw_first_image/'
root = 'C:/Users/glad/Desktop/graduate_code/Aug_test/'
save_root = 'C:/Users/glad/Desktop/graduate_code/output/'
#save_root2 = 'C:/Users/glad/Desktop/졸업/Trim_data_2s/'
#file_list = []
image_list = []
fourcc = cv2.VideoWriter_fourcc(*'mp4v')

# %%
file_list = os.listdir(image_root)
gt_list = []

# %%
for i in file_list:
    if i.split('.')[-1]=='txt':
        gt_list.append(i)

# %%
cap = cv2.VideoCapture(root+str(0)+".mp4")
w = round(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
print(w,h)
# Out:
# 1920 1080

# %%
out = cv2.VideoWriter('./' + "oiutput"+ ".mp4", fourcc, 30, (w, h))
for i in range(17):
    
    cap = cv2.VideoCapture(root+str(i)+".mp4")
    print(root+str(i)+".mp4")
    if cap.isOpened():
        while True:
            ret, img = cap.read()
            if ret:
                out.write(img)
            else:
                break
out.release()
# Out:
# C:/Users/glad/Desktop/graduate_code/Aug_test/0.mp4
# C:/Users/glad/Desktop/graduate_code/Aug_test/1.mp4
# C:/Users/glad/Desktop/graduate_code/Aug_test/2.mp4
# C:/Users/glad/Desktop/graduate_code/Aug_test/3.mp4
# C:/Users/glad/Desktop/graduate_code/Aug_test/4.mp4
# C:/Users/glad/Desktop/graduate_code/Aug_test/5.mp4
# C:/Users/glad/Desktop/graduate_code/Aug_test/6.mp4
# C:/Users/glad/Desktop/graduate_code/Aug_test/7.mp4
# C:/Users/glad/Desktop/graduate_code/Aug_test/8.mp4
# C:/Users/glad/Desktop/graduate_code/Aug_test/9.mp4
# C:/Users/glad/Desktop/graduate_code/Aug_test/10.mp4
# C:/Users/glad/Desktop/graduate_code/Aug_test/11.mp4
# C:/Users/glad/Desktop/graduate_code/Aug_test/12.mp4
# C:/Users/glad/Desktop/graduate_code/Aug_test/13.mp4
# C:/Users/glad/Desktop/graduate_code/Aug_test/14.mp4
# C:/Users/glad/Desktop/graduate_code/Aug_test/15.mp4
# C:/Users/glad/Desktop/graduate_code/Aug_test/16.mp4

# %%
files =  os.listdir(root)
files
# Out:
# ['test3.mp4']

# %%
# import time
# for i in range(len(files)):
#     image_list = []
    
#     #cap.release()
#     #out.release()
#     video_file = root+files[i] # 동영상 파일 경로
#     txt_file = image_root+gt_list[i]
#     print(video_file)
#     print(txt_file)
#     cap = cv2.VideoCapture(video_file) # 동영상 캡쳐 객체 생성  ---①
#     with open(txt_file,'r') as f:
#         line = f.readline()
#         if not line:
#             break
#         obj_id,x1,y1,x2,y2 = line.split(',')[1:]
#         #print(obj_id)
#         if int(obj_id) == 0:
#             obj_id,x1,y1,x2,y2 = line.split(',')[1:]
#         else:
#             line = f.readline()
#             obj_id,x1,y1,x2,y2 = line.split(',')[1:]
#     print(obj_id,x1,y1,x2,y2)
#     if cap.isOpened(): # 캡쳐 객체 초기화 확인
#         #w = round(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
#         #h = round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
#         while True:

            
#             ret, img = cap.read()      # 다음 프레임 읽기      --- ②
#             #print(img)
            
#             if ret:                     # 프레임 읽기 정상
#                 img = img[int(y1):int(y2),int(x1):int(x2)]
#                 w = int(x2)-int(x1)
#                 h = int(y2)-int(y1)
#                 #img = img[145:490,0:545]
#                 image_list.append(img)
#             else:                       # 다음 프레임 읽을 수 없슴,
#                 break                   # 재생 완료
#     else:
#         print("can't open video.")      # 캡쳐 객체 초기화 실패
#     #image_list = image_list[-15:]
#     print(len(image_list))
#     cap.release()                       # 캡쳐 자원 반납
#     out = cv2.VideoWriter(save_root+files[i], fourcc, 30, (w, h))
#     for k in image_list:
#         out.write(k)
#     out.release()
#     #time.sleep(1)

# %%
#video_w = 1920
#video_h = 1080

# %%
import time
ratio = 0 # get ratio +1
x_offset = 0
x_offset_2 = 0
y_offset = 0
y_offset_2 = 0
for i in range(len(files)):
    image_list = []
    
    #cap.release()
    #out.release()
    video_file = root+files[i] # 동영상 파일 경로
    txt_file = image_root+gt_list[i]
    print(video_file)
    print(txt_file)
    cap = cv2.VideoCapture(video_file) # 동영상 캡쳐 객체 생성  ---①
    video_w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    video_h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    print("length:",video_w,video_h)
    with open(txt_file,'r') as f:
        line = f.readline()
        if not line:
            break
        obj_id,x1,y1,x2,y2 = line.split(',')[1:]
        #print(obj_id)
        if int(obj_id) == 0:
            obj_id,x1,y1,x2,y2 = line.split(',')[1:]
        else:
            line = f.readline()
            obj_id,x1,y1,x2,y2 = line.split(',')[1:]
    print(obj_id,x1,y1,x2,y2)
    obj_id,x1,y1,x2,y2 = [int(x) for x in [obj_id,x1,y1,x2,y2]]
    w = int(x2+(x2-x1)*ratio/2) - int(x1-(x2-x1)*ratio/2)
    h = int(y2+(y2-y1)*ratio/2) - int(y1-(y2-y1)*ratio/2)
    
    print(int(x1-(x2-x1)*ratio/2),int(x2+(x2-x1)*ratio/2),int(y1-(y2-y1)*ratio/2),int(y2+(y2-y1)*ratio/2))
    print("w,h",w,h)
    print(int(x1-(x2-x1)*ratio/2))
    print(int(y1-(y2-y1)*ratio/2))
    if int(x1-(x2-x1)*ratio/2) < 0:
        x_offset = -int(x1-(x2-x1)*ratio/2)
    else:
        x_offset = 0
    if int(x2+(x2-x1)*ratio/2) > video_w:
        x_offset_2 = int(x2+(x2-x1)*ratio/2)-video_w
    else:
        x_offset_2 = 0
    if int(y2+(y2-y1)*ratio/2) > video_h:
        y_offset_2 = int(y2+(y2-y1)*ratio/2)-video_h
    else:
        y_offset_2 = 0
    if int(y1-(y2-y1)*ratio/2) < 0:
        y_offset = -int(y1-(y2-y1)*ratio/2)
    else:
        y_offset = 0
    #x_offset =
    #y_offset =
    base = np.zeros([h,w,3])
    print("x_offset,y_offset",x_offset,y_offset)
    print("x_offset_2,y_offest_2",x_offset_2,y_offset_2)
    out = cv2.VideoWriter(save_root+files[i].split('.')[0]+'.mp4', fourcc, 30, (w, h))
    if cap.isOpened(): # 캡쳐 객체 초기화 확인
        #w = round(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        #h = round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        while True:

            
            ret, img = cap.read()      # 다음 프레임 읽기      --- ②
            #print(img.shape)
            #print(img)
            
            if ret:                     # 프레임 읽기 정상
                #print(int(y1-(y2-y1)*ratio/2)+y_offset:int(y2+(y2-y1)*ratio/2)-y_offset_2,int(x1-(x2-x1)*ratio/2)+x_offset:int(x2+(x2-x1)*ratio/2)-x_offset_2)
                img = img[(int(y1-(y2-y1)*ratio/2)+y_offset):(int(y2+(y2-y1)*ratio/2)-y_offset_2),(int(x1-(x2-x1)*ratio/2)+x_offset):(int(x2+(x2-x1)*ratio/2)-x_offset_2)]
                y,x,c = img.shape[0],img.shape[1],img.shape[2]
                #print(y,x,c)
                #print(h-y_offset-y_offset_2)
                #img = np.concatenate([np.zeros([y_offset,w-x_offset-x_offset_2,3]),img],axis=0)
                img = np.concatenate([np.zeros([y_offset,x,3],dtype=np.uint8),img],axis=0)
                y,x,c = img.shape[0],img.shape[1],img.shape[2]
                #img = np.concatenate([img,np.zeros([y_offset_2,w-x_offset-x_offset_2,3])],axis=0)
                img = np.concatenate([img,np.zeros([y_offset_2,x,3],dtype=np.uint8)],axis=0)
                y,x,c = img.shape[0],img.shape[1],img.shape[2]
                #img = np.concatenate([np.zeros([h-y_offset-y_offset_2,x_offset,3]),img],axis=1)
                img = np.concatenate([np.zeros([y,x_offset,3],dtype=np.uint8),img],axis=1)
                y,x,c = img.shape[0],img.shape[1],img.shape[2]
                img = np.concatenate([img,np.zeros([y,x_offset_2,3],dtype=np.uint8)],axis=1)
                #img = np.concatenate([img,np.zeros([h-y_offset-y_offset_2,x_offset_2,3])],axis=1)
                
                #print(img.dtype)
                #print(img.shape)
                #img = cv2.add(img,base,dtype = cv2.CV_8U)
                #img = base + img +img
                #print(img)
                #print(base.shape)
                #print(img.shape)
                #w = int(x2)-int(x1)
                #h = int(y2)-int(y1)
                
                #w = int(x2+(x2-x1)*ratio/2) - int(x1-(x2-x1)*ratio/2)
                #h = int(y2+(y2-y1)*ratio/2) - int(y1-(y2-y1)*ratio/2)
                #img = img[145:490,0:545]
                out.write(img)
                #image_list.append(img)
            else:                       # 다음 프레임 읽을 수 없슴,
                break                   # 재생 완료
    else:
        print("can't open video.")      # 캡쳐 객체 초기화 실패
    #image_list = image_list[-15:]
    print(len(image_list))
    cap.release()                       # 캡쳐 자원 반납
    
    #for k in image_list:
        
    out.release()
    #time.sleep(1)
# Out:
# C:/Users/glad/Desktop/graduate_code/video/test3.mp4
# C:/Users/glad/Desktop/graduate_code/real_data_raw_first_image/test3.txt
# length: 1920 1080
# 0 350 76 938 401
#
# 350 938 76 401
# w,h 588 325
# 350
# 76
# x_offset,y_offset 0 0
# x_offset_2,y_offest_2 0 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [10], line 78
#      74 y,x,c = img.shape[0],img.shape[1],img.shape[2]
#      75 #print(y,x,c)
#      76 #print(h-y_offset-y_offset_2)
#      77 #img = np.concatenate([np.zeros([y_offset,w-x_offset-x_offset_2,3]),img],axis=0)
# ---> 78 img = np.concatenate([np.zeros([y_offset,x,3],dtype=np.uint8),img],axis=0)
#      79 y,x,c = img.shape[0],img.shape[1],img.shape[2]
#      80 #img = np.concatenate([img,np.zeros([y_offset_2,w-x_offset-x_offset_2,3])],axis=0)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
print(int(x2+(x2-x1)*ratio/2)-x_offset_2-1)
# Out:
# 1279.0

# %%
int(x2+(x2-x1)*ratio/2)
# Out:
# 1327

# %%
(int(x1-(x2-x1)*ratio/2)+x_offset)
# Out:
# 1085

# %%
import time
ratio = 1.33
x_offset = 0
x_offset_2 = 0
y_offset = 0
y_offset_2 = 0
for i in range(len(files)):
    image_list = []
    
    #cap.release()
    #out.release()
    video_file = root+files[i] # 동영상 파일 경로
    txt_file = image_root+gt_list[i]
    print(video_file)
    print(txt_file)
    cap = cv2.VideoCapture(video_file) # 동영상 캡쳐 객체 생성  ---①
    with open(txt_file,'r') as f:
        line = f.readline()
        if not line:
            break
        obj_id,x1,y1,x2,y2 = line.split(',')[1:]
        #print(obj_id)
        if int(obj_id) == 0:
            obj_id,x1,y1,x2,y2 = line.split(',')[1:]
        else:
            line = f.readline()
            obj_id,x1,y1,x2,y2 = line.split(',')[1:]
    print(obj_id,x1,y1,x2,y2)
    obj_id,x1,y1,x2,y2 = [int(x) for x in [obj_id,x1,y1,x2,y2]]
    w = int(x2+(x2-x1)*ratio/2) - int(x1-(x2-x1)*ratio/2)
    h = int(y2+(y2-y1)*ratio/2) - int(y1-(y2-y1)*ratio/2)
    
    print(int(x1-(x2-x1)*ratio/2),int(x2+(x2-x1)*ratio/2),int(y1-(y2-y1)*ratio/2),int(y2+(y2-y1)*ratio/2))
    print(w,h)
    print(int(x1-(x2-x1)*ratio/2))
    print(int(y1-(y2-y1)*ratio/2))
    if int(x1-(x2-x1)*ratio/2) < 0:
        x_offset = -int(x1-(x2-x1)*ratio/2)
    else:
        x_offset = 0
    if int(x2+(x2-x1)*ratio/2) > 1920:
        x_offset_2 = int(x2+(x2-x1)*ratio/2)-1920
    else:
        x_offset_2 = 0
    if int(y2+(y2-y1)*ratio/2) > 1080:
        y_offset_2 = int(y2+(y2-y1)*ratio/2)-1080
    else:
        y_offset_2 = 0
    if int(y1-(y2-y1)*ratio/2) < 0:
        y_offset = -int(y1-(y2-y1)*ratio/2)
    else:
        y_offset = 0
    #x_offset =
    #y_offset =
    base = np.zeros([h,w,3])
    print(x_offset,y_offset)
    print(x_offset_2,y_offset_2)
    if cap.isOpened(): # 캡쳐 객체 초기화 확인
        #w = round(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        #h = round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        while True:

            
            ret, img = cap.read()      # 다음 프레임 읽기      --- ②
            #print(img.shape)
            #print(img)
            
            if ret:                     # 프레임 읽기 정상
                
                img = img[int(y1-(y2-y1)*ratio/2)+y_offset:int(y2+(y2-y1)*ratio/2)-y_offset_2,int(x1-(x2-x1)*ratio/2)+x_offset:int(x2+(x2-x1)*ratio/2)-x_offset_2]
                y,x,c = img.shape[0],img.shape[1],img.shape[2]
                #print(y,x,c)
                #print(h-y_offset-y_offset_2)
                #img = np.concatenate([np.zeros([y_offset,w-x_offset-x_offset_2,3]),img],axis=0)
                img = np.concatenate([np.zeros([y_offset,x,3],dtype=np.uint8),img],axis=0)
                y,x,c = img.shape[0],img.shape[1],img.shape[2]
                #img = np.concatenate([img,np.zeros([y_offset_2,w-x_offset-x_offset_2,3])],axis=0)
                img = np.concatenate([img,np.zeros([y_offset_2,x,3],dtype=np.uint8)],axis=0)
                y,x,c = img.shape[0],img.shape[1],img.shape[2]
                #img = np.concatenate([np.zeros([h-y_offset-y_offset_2,x_offset,3]),img],axis=1)
                img = np.concatenate([np.zeros([y,x_offset,3],dtype=np.uint8),img],axis=1)
                y,x,c = img.shape[0],img.shape[1],img.shape[2]
                img = np.concatenate([img,np.zeros([y,x_offset_2,3],dtype=np.uint8)],axis=1)
                #img = np.concatenate([img,np.zeros([h-y_offset-y_offset_2,x_offset_2,3])],axis=1)
                
                #print(img.dtype)
                #print(img.shape)
                #img = cv2.add(img,base,dtype = cv2.CV_8U)
                #img = base + img +img
                #print(img)
                #print(base.shape)
                #print(img.shape)
                #w = int(x2)-int(x1)
                #h = int(y2)-int(y1)
                
                #w = int(x2+(x2-x1)*ratio/2) - int(x1-(x2-x1)*ratio/2)
                #h = int(y2+(y2-y1)*ratio/2) - int(y1-(y2-y1)*ratio/2)
                #img = img[145:490,0:545]
                image_list.append(img)
            else:                       # 다음 프레임 읽을 수 없슴,
                break                   # 재생 완료
    else:
        print("can't open video.")      # 캡쳐 객체 초기화 실패
    #image_list = image_list[-15:]
    print(len(image_list))
    cap.release()                       # 캡쳐 자원 반납
    out = cv2.VideoWriter(save_root+files[i].split('.')[0]+'_up.mp4', fourcc, 30, (w, h))
    for k in image_list:
        out.write(k)
    out.release()
    #time.sleep(1)
# Out:
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0001_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0001_Trim.txt
# 0 437 237 768 413
#
# 216 988 119 530
# 772 411
# 216
# 119
# 0 0
# 0 0
# 90
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0002_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0002_Trim.txt
# 0 436 234 768 417
#
# 215 988 112 538
# 773 426
# 215
# 112
# 0 0
# 0 0
# 91
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0003_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0003_Trim.txt
# 0 425 237 756 415
#
# 204 976 118 533
# 772 415
# 204
# 118
# 0 0
# 0 0
# 92
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0004_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0004_Trim.txt
# 0 447 234 778 414
#
# 226 998 114 533
# 772 419
# 226
# 114
# 0 0
# 0 0
# 91
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0005_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0005_Trim.txt
# 0 438 233 769 417
#
# 217 989 110 539
# 772 429
# 217
# 110
# 0 0
# 0 0
# 91
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0006_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0006_Trim.txt
# 0 442 237 773 411
#
# 221 993 121 526
# 772 405
# 221
# 121
# 0 0
# 0 0
# 92
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0007_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0007_Trim.txt
# 0 439 234 773 407
#
# 216 995 118 522
# 779 404
# 216
# 118
# 0 0
# 0 0
# 91
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0009_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0009_Trim.txt
# 0 427 236 755 407
#
# 208 973 122 520
# 765 398
# 208
# 122
# 0 0
# 0 0
# 90
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0010_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0033_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0033_Trim.txt
# 0 400 186 693 319
#
# 205 887 97 407
# 682 310
# 205
# 97
# 0 0
# 0 0
# 121
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0034_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0034_Trim.txt
# 0 421 67 723 207
#
# 220 923 -26 300
# 703 326
# 220
# -26
# 0 26
# 0 0
# 118
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0035_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0035_Trim.txt
# 0 404 70 703 209
#
# 205 901 -22 301
# 696 323
# 205
# -22
# 0 22
# 0 0
# 91
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0036_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0036_Trim.txt
# 0 482 277 778 413
#
# 285 974 186 503
# 689 317
# 285
# 186
# 0 0
# 0 0
# 111
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0036_Trim_1.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0037_Trim.txt
# 0 467 274 760 409
#
# 272 954 184 498
# 682 314
# 272
# 184
# 0 0
# 0 0
# 111
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0037_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0038_Trim(1).txt
# 0 456 275 747 409
#
# 262 940 185 498
# 678 313
# 262
# 185
# 0 0
# 0 0
# 120
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0038_Trim(1).mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0038_Trim(2).txt
# 0 456 275 747 409
#
# 262 940 185 498
# 678 313
# 262
# 185
# 0 0
# 0 0
# 110
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0038_Trim(2).mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0039_Trim.txt
# 0 482 277 778 413
#
# 285 974 186 503
# 689 317
# 285
# 186
# 0 0
# 0 0
# 135
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0039_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0040_Trim.txt
# 0 419 67 715 210
#
# 222 911 -28 305
# 689 333
# 222
# -28
# 0 28
# 0 0
# 108
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0040_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0041_Trim.txt
# 0 423 67 719 210
#
# 226 915 -28 305
# 689 333
# 226
# -28
# 0 28
# 0 0
# 119
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0041_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0042_Trim.txt
# 0 423 67 719 210
#
# 226 915 -28 305
# 689 333
# 226
# -28
# 0 28
# 0 0
# 94
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0042_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0043_Trim.txt
# 0 416 66 712 208
#
# 219 908 -28 302
# 689 330
# 219
# -28
# 0 28
# 0 0
# 103
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0043_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0044_Trim.txt
# 0 416 66 712 208
#
# 219 908 -28 302
# 689 330
# 219
# -28
# 0 28
# 0 0
# 102
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0044_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0045_Trim.txt
# 0 427 183 723 318
#
# 230 919 93 407
# 689 314
# 230
# 93
# 0 0
# 0 0
# 105
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0045_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0046_Trim.txt
# 0 427 183 723 318
#
# 230 919 93 407
# 689 314
# 230
# 93
# 0 0
# 0 0
# 100
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0046_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0047_Trim.txt
# 0 409 169 703 303
#
# 213 898 79 392
# 685 313
# 213
# 79
# 0 0
# 0 0
# 94
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0047_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0048_Trim.txt
# 0 409 173 704 303
#
# 212 900 86 389
# 688 303
# 212
# 86
# 0 0
# 0 0
# 116
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0048_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0049_Trim.txt
# 0 411 173 704 303
#
# 216 898 86 389
# 682 303
# 216
# 86
# 0 0
# 0 0
# 116
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0049_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0050_Trim.txt
# 0 449 62 742 192
#
# 254 936 -24 278
# 682 302
# 254
# -24
# 0 24
# 0 0
# 112
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0050_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0051_Trim.txt
# 0 449 62 742 192
#
# 254 936 -24 278
# 682 302
# 254
# -24
# 0 24
# 0 0
# 111
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0051_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0052_Trim.txt
# 0 446 80 742 211
#
# 249 938 -7 298
# 689 305
# 249
# -7
# 0 7
# 0 0
# 108
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0052_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0053_Trim.txt
# 0 446 80 742 211
#
# 249 938 -7 298
# 689 305
# 249
# -7
# 0 7
# 0 0
# 115
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0053_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0054_Trim(1).txt
# 0 461 78 759 210
#
# 262 957 -9 297
# 695 306
# 262
# -9
# 0 9
# 0 0
# 100
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0054_Trim(1).mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0054_Trim(2).txt
# 0 461 78 759 210
#
# 262 957 -9 297
# 695 306
# 262
# -9
# 0 9
# 0 0
# 104
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0054_Trim(2).mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0055_Trim.txt
# 0 459 77 755 209
#
# 262 951 -10 296
# 689 306
# 262
# -10
# 0 10
# 0 0
# 105
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0055_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0056_Trim.txt
# 0 460 78 756 210
#
# 263 952 -9 297
# 689 306
# 263
# -9
# 0 9
# 0 0
# 111
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0056_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0057_Trim.txt
# 0 460 78 756 210
#
# 263 952 -9 297
# 689 306
# 263
# -9
# 0 9
# 0 0
# 111
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0057_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0058_Trim.txt
# 0 457 79 752 211
#
# 260 948 -8 298
# 688 306
# 260
# -8
# 0 8
# 0 0
# 115
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0058_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0059_Trim.txt
# 0 458 78 749 210
#
# 264 942 -9 297
# 678 306
# 264
# -9
# 0 9
# 0 0
# 117
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0059_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LA_VE_0060_Trim.txt
# 0 457 78 748 210
#
# 263 941 -9 297
# 678 306
# 263
# -9
# 0 9
# 0 0
# 100
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LA_VE_0060_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0001_Trim.txt
# 0 452 233 788 410
#
# 228 1011 115 527
# 783 412
# 228
# 115
# 0 0
# 0 0
# 111
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0001_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0002_Trim.txt
# 0 452 233 788 410
#
# 228 1011 115 527
# 783 412
# 228
# 115
# 0 0
# 0 0
# 128
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0002_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0003_Trim.txt
# 0 451 232 785 410
#
# 228 1007 113 528
# 779 415
# 228
# 113
# 0 0
# 0 0
# 112
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0003_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0004_Trim.txt
# 0 452 232 786 410
#
# 229 1008 113 528
# 779 415
# 229
# 113
# 0 0
# 0 0
# 123
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0004_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0005_Trim.txt
# 0 453 230 787 410
#
# 230 1009 110 529
# 779 419
# 230
# 110
# 0 0
# 0 0
# 96
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0005_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0006_Trim.txt
# 0 452 230 786 410
#
# 229 1008 110 529
# 779 419
# 229
# 110
# 0 0
# 0 0
# 97
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0006_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0007_Trim.txt
# 0 451 231 785 410
#
# 228 1007 111 529
# 779 418
# 228
# 111
# 0 0
# 0 0
# 111
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0007_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0008_Trim.txt
# 0 452 231 786 410
#
# 229 1008 111 529
# 779 418
# 229
# 111
# 0 0
# 0 0
# 121
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0008_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0009_Trim.txt
# 0 452 231 786 409
#
# 229 1008 112 527
# 779 415
# 229
# 112
# 0 0
# 0 0
# 115
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0009_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0010_Trim.txt
# 0 461 272 754 401
#
# 266 948 186 486
# 682 300
# 266
# 186
# 0 0
# 0 0
# 106
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0010_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0011_Trim.txt
# 0 458 272 751 401
#
# 263 945 186 486
# 682 300
# 263
# 186
# 0 0
# 0 0
# 100
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0011_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0012_Trim.txt
# 0 464 272 755 404
#
# 270 948 184 491
# 678 307
# 270
# 184
# 0 0
# 0 0
# 108
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0012_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_
Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0035_Trim.txt
# 0 419 184 716 322
#
# 221 913 92 413
# 692 321
# 221
# 92
# 0 0
# 0 0
# 120
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0035_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0036_Trim.txt
# 0 421 184 718 322
#
# 223 915 92 413
# 692 321
# 223
# 92
# 0 0
# 0 0
# 112
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0037_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0037_Trim.txt
# 0 408 169 700 307
#
# 213 894 77 398
# 681 321
# 213
# 77
# 0 0
# 0 0
# 127
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0038_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0038_Trim.txt
# 0 403 169 695 307
#
# 208 889 77 398
# 681 321
# 208
# 77
# 0 0
# 0 0
# 96
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0039_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0039_Trim.txt
# 0 403 168 695 306
#
# 208 889 76 397
# 681 321
# 208
# 76
# 0 0
# 0 0
# 107
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0040_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0040_Trim.txt
# 0 406 169 698 307
#
# 211 892 77 398
# 681 321
# 211
# 77
# 0 0
# 0 0
# 113
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0041_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0041_Trim.txt
# 0 407 169 699 307
#
# 212 893 77 398
# 681 321
# 212
# 77
# 0 0
# 0 0
# 105
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0042_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0042_Trim.txt
# 0 409 170 701 308
#
# 214 895 78 399
# 681 321
# 214
# 78
# 0 0
# 0 0
# 110
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0043_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0043_Trim.txt
# 0 445 109 738 247
#
# 250 932 17 338
# 682 321
# 250
# 17
# 0 0
# 0 0
# 99
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0044_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0044_Trim.txt
# 0 445 109 738 247
#
# 250 932 17 338
# 682 321
# 250
# 17
# 0 0
# 0 0
# 111
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0045_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0045_Trim.txt
# 0 448 108 740 246
#
# 253 934 16 337
# 681 321
# 253
# 16
# 0 0
# 0 0
# 97
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0046_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0046_Trim.txt
# 0 445 108 738 246
#
# 250 932 16 337
# 682 321
# 250
# 16
# 0 0
# 0 0
# 100
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0047_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0047_Trim.txt
# 0 455 75 750 219
#
# 258 946 -20 314
# 688 334
# 258
# -20
# 0 20
# 0 0
# 115
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0048_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0048_Trim.txt
# 0 456 75 751 219
#
# 259 947 -20 314
# 688 334
# 259
# -20
# 0 20
# 0 0
# 108
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0049_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0049_Trim.txt
# 0 457 75 752 219
#
# 260 948 -20 314
# 688 334
# 260
# -20
# 0 20
# 0 0
# 111
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0050_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0050_Trim.txt
# 0 467 28 762 172
#
# 270 958 -67 267
# 688 334
# 270
# -67
# 0 67
# 0 0
# 94
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0051_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0051_Trim.txt
# 0 465 29 759 171
#
# 269 954 -65 265
# 685 330
# 269
# -65
# 0 65
# 0 0
# 127
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0052_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0052_Trim.txt
# 0 466 29 760 171
#
# 270 955 -65 265
# 685 330
# 270
# -65
# 0 65
# 0 0
# 126
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0053_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0053_Trim.txt
# 0 462 28 756 170
#
# 266 951 -66 264
# 685 330
# 266
# -66
# 0 66
# 0 0
# 141
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_SE_0054_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_SE_0054_Trim.txt
# 0 468 30 762 172
#
# 272 957 -64 266
# 685 330
# 272
# -64
# 0 64
# 0 0
# 106
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0001_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0001_Trim.txt
# 0 437 234 763 416
#
# 220 979 112 537
# 759 425
# 220
# 112
# 0 0
# 0 0
# 167
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0002_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0002_Trim.txt
# 0 437 234 769 416
#
# 216 989 112 537
# 773 425
# 216
# 112
# 0 0
# 0 0
# 114
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_
Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0045_Trim.txt
# 0 417 75 713 215
#
# 220 909 -18 308
# 689 326
# 220
# -18
# 0 18
# 0 0
# 92
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0046_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0046_Trim.txt
# 0 417 68 713 208
#
# 220 909 -25 301
# 689 326
# 220
# -25
# 0 25
# 0 0
# 93
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0047_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0047_Trim.txt
# 0 417 68 713 208
#
# 220 909 -25 301
# 689 326
# 220
# -25
# 0 25
# 0 0
# 104
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0048_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0048_Trim.txt
# 0 418 68 714 208
#
# 221 910 -25 301
# 689 326
# 221
# -25
# 0 25
# 0 0
# 104
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0049_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0049_Trim.txt
# 0 417 69 713 209
#
# 220 909 -24 302
# 689 326
# 220
# -24
# 0 24
# 0 0
# 121
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0050_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0050_Trim.txt
# 0 497 255 774 352
#
# 312 958 190 416
# 646 226
# 312
# 190
# 0 0
# 0 0
# 95
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0051_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0051_Trim.txt
# 0 412 170 703 302
#
# 218 896 82 389
# 678 307
# 218
# 82
# 0 0
# 0 0
# 94
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0052_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0052_Trim.txt
# 0 454 112 745 244
#
# 260 938 24 331
# 678 307
# 260
# 24
# 0 0
# 0 0
# 105
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0053_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0053_Trim.txt
# 0 453 112 744 244
#
# 259 937 24 331
# 678 307
# 259
# 24
# 0 0
# 0 0
# 103
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0054_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0054_Trim.txt
# 0 453 112 744 244
#
# 259 937 24 331
# 678 307
# 259
# 24
# 0 0
# 0 0
# 112
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0055_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0055_Trim.txt
# 0 450 69 741 201
#
# 256 934 -18 288
# 678 306
# 256
# -18
# 0 18
# 0 0
# 102
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0056_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0056_Trim.txt
# 0 450 69 741 201
#
# 256 934 -18 288
# 678 306
# 256
# -18
# 0 18
# 0 0
# 103
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0057_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0057_Trim.txt
# 0 450 69 741 201
#
# 256 934 -18 288
# 678 306
# 256
# -18
# 0 18
# 0 0
# 103
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0058_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0058_Trim.txt
# 0 450 68 741 200
#
# 256 934 -19 287
# 678 306
# 256
# -19
# 0 19
# 0 0
# 107
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0059_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0059_Trim.txt
# 0 450 68 741 200
#
# 256 934 -19 287
# 678 306
# 256
# -19
# 0 19
# 0 0
# 105
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0060_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0060_Trim.txt
# 0 450 66 740 198
#
# 257 932 -21 285
# 675 306
# 257
# -21
# 0 21
# 0 0
# 110
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0061_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0061_Trim.txt
# 0 450 66 741 198
#
# 256 934 -21 285
# 678 306
# 256
# -21
# 0 21
# 0 0
# 102
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_VE_0062_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_VE_0062_Trim.txt
# 0 462 77 755 216
#
# 267 949 -15 308
# 682 323
# 267
# -15
# 0 15
# 0 0
# 103
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0001_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0001_Trim.txt
# 0 454 229 783 405
#
# 235 1001 111 522
# 766 411
# 235
# 111
# 0 0
# 0 0
# 101
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0002_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0002_Trim.txt
# 0 456 229 785 405
#
# 237 1003 111 522
# 766 411
# 237
# 111
# 0 0
# 0 0
# 132
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0003_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0003_Trim.txt
# 0 456 231 785 405
#
# 237 1003 115 520
# 766 405
# 237
# 115
# 0 0
# 0 0
# 131
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0004_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0004_Trim.txt
# 0 457 231 786 405
#
# 238 1004 115 520
# 766 405
# 238
# 115
# 0 0
# 0 0
# 113
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0005_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0005_Trim.txt
# 0 456 231 785 405
#
# 237 1003 115 520
# 766 405
# 237
# 115
# 0 0
# 0 0
# 112
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0006_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0006_Trim.txt
# 0 456 231 785 405
#
# 237 1003 115 520
# 766 405
# 237
# 115
# 0 0
# 0 0
# 93
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0007_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0007_Trim.txt
# 0 457 231 786 405
#
# 238 1004 115 520
# 766 405
# 238
# 115
# 0 0
# 0 0
# 124
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0008_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0008_Trim.txt
# 0 457 231 786 405
#
# 238 1004 115 520
# 766 405
# 238
# 115
# 0 0
# 0 0
# 107
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0009_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0009_Trim.txt
# 0 457 231 786 405
#
# 238 1004 115 520
# 766 405
# 238
# 115
# 0 0
# 0 0
# 114
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0010_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0010_Trim.txt
# 0 457 231 786 405
#
# 238 1004 115 520
# 766 405
# 238
# 115
# 0 0
# 0 0
# 105
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0011_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0011_Trim.txt
# 0 466 271 753 402
#
# 275 943 183 489
# 668 306
# 275
# 183
# 0 0
# 0 0
# 103
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0012_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0012_Trim.txt
# 0 466 271 753 402
#
# 275 943 183 489
# 668 306
# 275
# 183
# 0 0
# 0 0
# 113
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0013_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0013_Trim.txt
# 0 466 271 753 402
#
# 275 943 183 489
# 668 306
# 275
# 183
# 0 0
# 0 0
# 119
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0014_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0014_Trim.txt
# 0 467 271 754 402
#
# 276 944 183 489
# 668 306
# 276
# 183
# 0 0
# 0 0
# 111
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0015_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0015_Trim.txt
# 0 467 271 754 402
#
# 276 944 183 489
# 668 306
# 276
# 183
# 0 0
# 0 0
# 113
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0016_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0016_Trim.txt
# 0 467 271 754 402
#
# 276 944 183 489
# 668 306
# 276
# 183
# 0 0
# 0 0
# 100
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0017_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0017_Trim.txt
# 0 467 271 754 402
#
# 276 944 183 489
# 668 306
# 276
# 183
# 0 0
# 0 0
# 101
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0018_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0018_Trim.txt
# 0 466 271 753 402
#
# 275 943 183 489
# 668 306
# 275
# 183
# 0 0
# 0 0
# 115
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0019_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0019_Trim.txt
# 0 467 271 754 402
#
# 276 944 183 489
# 668 306
# 276
# 183
# 0 0
# 0 0
# 118
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0020_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0020_Trim.txt
# 0 466 271 753 402
#
# 275 943 183 489
# 668 306
# 275
# 183
# 0 0
# 0 0
# 98
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0021_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0021_Trim.txt
# 0 439 267 731 398
#
# 244 925 179 485
# 681 306
# 244
# 179
# 0 0
# 0 0
# 125
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0022_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0022_Trim.txt
# 0 439 267 731 398
#
# 244 925 179 485
# 681 306
# 244
# 179
# 0 0
# 0 0
# 107
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0023_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0023_Trim.txt
# 0 439 267 731 398
#
# 244 925 179 485
# 681 306
# 244
# 179
# 0 0
# 0 0
# 129
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0024_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0024_Trim.txt
# 0 439 267 731 398
#
# 244 925 179 485
# 681 306
# 244
# 179
# 0 0
# 0 0
# 130
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0025_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0025_Trim.txt
# 0 439 267 731 398
#
# 244 925 179 485
# 681 306
# 244
# 179
# 0 0
# 0 0
# 116
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0026_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0026_Trim.txt
# 0 438 267 730 398
#
# 243 924 179 485
# 681 306
# 243
# 179
# 0 0
# 0 0
# 117
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0027_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0027_Trim.txt
# 0 471 30 763 156
#
# 276 957 -53 239
# 681 292
# 276
# -53
# 0 53
# 0 0
# 97
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0028_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0028_Trim.txt
# 0 427 183 719 314
#
# 232 913 95 401
# 681 306
# 232
# 95
# 0 0
# 0 0
# 95
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0029_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0029_Trim.txt
# 0 426 182 718 313
#
# 231 912 94 400
# 681 306
# 231
# 94
# 0 0
# 0 0
# 104
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0030_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0030_Trim.txt
# 0 427 183 719 314
#
# 232 913 95 401
# 681 306
# 232
# 95
# 0 0
# 0 0
# 149
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0031_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0031_Trim.txt
# 0 427 182 719 313
#
# 232 913 94 400
# 681 306
# 232
# 94
# 0 0
# 0 0
# 117
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0032_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0032_Trim.txt
# 0 427 182 719 313
#
# 232 913 94 400
# 681 306
# 232
# 94
# 0 0
# 0 0
# 114
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0033_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0033_Trim.txt
# 0 427 182 719 313
#
# 232 913 94 400
# 681 306
# 232
# 94
# 0 0
# 0 0
# 99
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0034_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0034_Trim.txt
# 0 427 182 719 313
#
# 232 913 94 400
# 681 306
# 232
# 94
# 0 0
# 0 0
# 110
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0035_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0035_Trim.txt
# 0 427 182 719 313
#
# 232 913 94 400
# 681 306
# 232
# 94
# 0 0
# 0 0
# 100
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0036_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0036_Trim.txt
# 0 427 183 719 314
#
# 232 913 95 401
# 681 306
# 232
# 95
# 0 0
# 0 0
# 107
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0037_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0037_Trim.txt
# 0 427 182 719 313
#
# 232 913 94 400
# 681 306
# 232
# 94
# 0 0
# 0 0
# 96
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0038_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0038_Trim.txt
# 0 453 112 742 243
#
# 260 934 24 330
# 674 306
# 260
# 24
# 0 0
# 0 0
# 103
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0039_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0039_Trim.txt
# 0 452 111 741 242
#
# 259 933 23 329
# 674 306
# 259
# 23
# 0 0
# 0 0
# 99
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0040_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0040_Trim.txt
# 0 454 111 743 242
#
# 261 935 23 329
# 674 306
# 261
# 23
# 0 0
# 0 0
# 107
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0041_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0041_Trim.txt
# 0 454 112 743 243
#
# 261 935 24 330
# 674 306
# 261
# 24
# 0 0
# 0 0
# 142
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0042_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0042_Trim.txt
# 0 454 112 743 243
#
# 261 935 24 330
# 674 306
# 261
# 24
# 0 0
# 0 0
# 99
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0043_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0043_Trim.txt
# 0 454 112 743 243
#
# 261 935 24 330
# 674 306
# 261
# 24
# 0 0
# 0 0
# 93
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0044_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0044_Trim.txt
# 0 454 112 743 243
#
# 261 935 24 330
# 674 306
# 261
# 24
# 0 0
# 0 0
# 103
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0045_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0045_Trim.txt
# 0 454 112 743 243
#
# 261 935 24 330
# 674 306
# 261
# 24
# 0 0
# 0 0
# 95
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0046_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0046_Trim.txt
# 0 454 111 743 242
#
# 261 935 23 329
# 674 306
# 261
# 23
# 0 0
# 0 0
# 104
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0047_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0047_Trim.txt
# 0 454 111 743 242
#
# 261 935 23 329
# 674 306
# 261
# 23
# 0 0
# 0 0
# 95
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0048_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0048_Trim.txt
# 0 467 30 763 169
#
# 270 959 -62 261
# 689 323
# 270
# -62
# 0 62
# 0 0
# 104
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0049_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0049_Trim.txt
# 0 468 30 764 169
#
# 271 960 -62 261
# 689 323
# 271
# -62
# 0 62
# 0 0
# 98
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0050_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0050_Trim.txt
# 0 470 30 766 169
#
# 273 962 -62 261
# 689 323
# 273
# -62
# 0 62
# 0 0
# 101
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0051_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0051_Trim.txt
# 0 462 29 758 168
#
# 265 954 -63 260
# 689 323
# 265
# -63
# 0 63
# 0 0
# 327
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0052_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0052_Trim.txt
# 0 462 28 758 167
#
# 265 954 -64 259
# 689 323
# 265
# -64
# 0 64
# 0 0
# 434
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0053_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_LS_LS_WE_0053_Trim.txt
# 0 462 28 758 167
#
# 265 954 -64 259
# 689 323
# 265
# -64
# 0 64
# 0 0
# 339
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_LS_LS_WE_0054_Trim.mp4
# ...
# 590
# 20
# 0 0
# 0 0
# 367
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_VE_0043_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_VE_0043_Trim.txt
# 0 700 116 864 260
#
# 590 973 20 355
# 383 335
# 590
# 20
# 0 0
# 0 0
# 378
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_VE_0044_1_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_VE_0044_1_Trim.txt
# 0 691 124 863 276
#
# 576 977 22 377
# 401 355
# 576
# 22
# 0 0
# 0 0
# 463
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_VE_0044_Trim(1).mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_VE_0044_Trim(1).txt
# 0 663 133 843 285
#
# 543 962 31 386
# 419 355
# 543
# 31
# 0 0
# 0 0
# 421
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_VE_0044_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_VE_0044_Trim.txt
# 0 663 133 843 285
#
# 543 962 31 386
# 419 355
# 543
# 31
# 0 0
# 0 0
# 429
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_VE_0045_Trim(1).mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_VE_0045_Trim(1).txt
# 0 703 112 864 262
#
# 595 971 12 361
# 376 349
# 595
# 12
# 0 0
# 0 0
# 358
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_VE_0046_1_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_VE_0046_1_Trim.txt
# 0 692 128 861 277
#
# 579 973 28 376
# 394 348
# 579
# 28
# 0 0
# 0 0
# 431
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_VE_0046_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_VE_0046_Trim.txt
# 0 665 140 844 285
#
# 545 963 43 381
# 418 338
# 545
# 43
# 0 0
# 0 0
# 364
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_VE_0047_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_VE_0047_Trim.txt
# 0 700 114 864 261
#
# 590 973 16 358
# 383 342
# 590
# 16
# 0 0
# 0 0
# 364
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_VE_0048_1_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_VE_0048_1_Trim.txt
# 0 689 130 862 276
#
# 573 977 32 373
# 404 341
# 573
# 32
# 0 0
# 0 0
# 412
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_VE_0048_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_VE_0048_Trim.txt
# 0 700 114 864 261
#
# 590 973 16 358
# 383 342
# 590
# 16
# 0 0
# 0 0
# 424
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_VE_0049_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_VE_0049_Trim.txt
# 0 700 114 865 260
#
# 590 974 16 357
# 384 341
# 590
# 16
# 0 0
# 0 0
# 423
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_VE_0050_1_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_VE_0050_1_Trim.txt
# 0 689 130 863 275
#
# 573 978 33 371
# 405 338
# 573
# 33
# 0 0
# 0 0
# 269
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_VE_0050_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_VE_0050_Trim.txt
# 0 700 114 864 260
#
# 590 973 16 357
# 383 341
# 590
# 16
# 0 0
# 0 0
# 375
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_VE_0051_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_VE_0051_Trim.txt
# 0 700 114 864 260
#
# 590 973 16 357
# 383 341
# 590
# 16
# 0 0
# 0 0
# 395
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_VE_0052_1_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_VE_0052_1_Trim.txt
# 0 691 131 865 276
#
# 575 980 34 372
# 405 338
# 575
# 34
# 0 0
# 0 0
# 380
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_VE_0052_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_VE_0052_Trim.txt
# 0 690 125 858 271
#
# 578 969 27 368
# 391 341
# 578
# 27
# 0 0
# 0 0
# 277
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_VE_0053_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_VE_0053_Trim.txt
# 0 704 117 864 262
#
# 597 970 20 358
# 373 338
# 597
# 20
# 0 0
# 0 0
# 358
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0001_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0001_Trim.txt
# 0 722 324 864 451
#
# 627 958 239 535
# 331 296
# 627
# 239
# 0 0
# 0 0
# 147
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0002_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0002_Trim.txt
# 0 722 324 864 451
#
# 627 958 239 535
# 331 296
# 627
# 239
# 0 0
# 0 0
# 219
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0003_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0003_Trim.txt
# 0 722 324 864 451
#
# 627 958 239 535
# 331 296
# 627
# 239
# 0 0
# 0 0
# 226
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0004_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0004_Trim.txt
# 0 722 324 864 451
#
# 627 958 239 535
# 331 296
# 627
# 239
# 0 0
# 0 0
# 259
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0005_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0005_Trim.txt
# 0 722 324 864 451
#
# 627 958 239 535
# 331 296
# 627
# 239
# 0 0
# 0 0
# 342
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0006_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0006_Trim.txt
# 0 722 324 864 451
#
# 627 958 239 535
# 331 296
# 627
# 239
# 0 0
# 0 0
# 228
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0007_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0007_Trim.txt
# 0 722 324 864 451
#
# 627 958 239 535
# 331 296
# 627
# 239
# 0 0
# 0 0
# 250
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0008_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0008_Trim.txt
# 0 722 324 864 451
#
# 627 958 239 535
# 331 296
# 627
# 239
# 0 0
# 0 0
# 277
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0009_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0009_Trim.txt
# 0 722 324 864 451
#
# 627 958 239 535
# 331 296
# 627
# 239
# 0 0
# 0 0
# 275
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0010_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0010_Trim.txt
# 0 722 324 864 451
#
# 627 958 239 535
# 331 296
# 627
# 239
# 0 0
# 0 0
# 216
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0011_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0011_Trim.txt
# 0 701 153 848 282
#
# 603 945 67 367
# 342 300
# 603
# 67
# 0 0
# 0 0
# 352
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0012_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0012_Trim.txt
# 0 701 153 848 282
#
# 603 945 67 367
# 342 300
# 603
# 67
# 0 0
# 0 0
# 335
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0013_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0013_Trim.txt
# 0 701 153 848 282
#
# 603 945 67 367
# 342 300
# 603
# 67
# 0 0
# 0 0
# 216
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0014_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0014_Trim.txt
# 0 701 153 848 282
#
# 603 945 67 367
# 342 300
# 603
# 67
# 0 0
# 0 0
# 319
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0015_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0015_Trim.txt
# 0 701 153 848 282
#
# 603 945 67 367
# 342 300
# 603
# 67
# 0 0
# 0 0
# 215
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0016_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0016_Trim.txt
# 0 701 153 848 282
#
# 603 945 67 367
# 342 300
# 603
# 67
# 0 0
# 0 0
# 197
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0017_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0017_Trim.txt
# 0 701 153 848 282
#
# 603 945 67 367
# 342 300
# 603
# 67
# 0 0
# 0 0
# 265
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0018_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0018_Trim.txt
# 0 701 153 848 282
#
# 603 945 67 367
# 342 300
# 603
# 67
# 0 0
# 0 0
# 277
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0019_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0019_Trim.txt
# 0 701 153 848 282
#
# 603 945 67 367
# 342 300
# 603
# 67
# 0 0
# 0 0
# 297
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0020_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0020_Trim.txt
# 0 701 153 848 282
#
# 603 945 67 367
# 342 300
# 603
# 67
# 0 0
# 0 0
# 349
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0021_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0021_Trim.txt
# 0 690 123 862 280
#
# 575 976 18 384
# 401 366
# 575
# 18
# 0 0
# 0 0
# 278
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0022_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0022_Trim.txt
# 0 690 123 862 280
#
# 575 976 18 384
# 401 366
# 575
# 18
# 0 0
# 0 0
# 362
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0023_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0023_Trim.txt
# 0 690 123 862 280
#
# 575 976 18 384
# 401 366
# 575
# 18
# 0 0
# 0 0
# 391
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0024_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0024_Trim.txt
# 0 690 123 862 280
#
# 575 976 18 384
# 401 366
# 575
# 18
# 0 0
# 0 0
# 255
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0025_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0025_Trim.txt
# 0 690 123 862 280
#
# 575 976 18 384
# 401 366
# 575
# 18
# 0 0
# 0 0
# 446
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0026_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0026_Trim.txt
# 0 690 123 862 280
#
# 575 976 18 384
# 401 366
# 575
# 18
# 0 0
# 0 0
# 401
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0027_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0027_Trim.txt
# 0 690 123 862 280
#
# 575 976 18 384
# 401 366
# 575
# 18
# 0 0
# 0 0
# 498
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0028_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0028_Trim.txt
# 0 690 123 862 280
#
# 575 976 18 384
# 401 366
# 575
# 18
# 0 0
# 0 0
# 506
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0029_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0029_Trim.txt
# 0 690 123 862 280
#
# 575 976 18 384
# 401 366
# 575
# 18
# 0 0
# 0 0
# 432
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0030_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0030_Trim.txt
# 0 700 111 865 267
#
# 590 974 7 370
# 384 363
# 590
# 7
# 0 0
# 0 0
# 206
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0031_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0031_Trim.txt
# 0 689 126 865 281
#
# 571 982 22 384
# 411 362
# 571
# 22
# 0 0
# 0 0
# 301
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0032_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0032_Trim.txt
# 0 700 111 866 266
#
# 589 976 7 369
# 387 362
# 589
# 7
# 0 0
# 0 0
# 143
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0033_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0033_Trim.txt
# 0 690 128 861 282
#
# 576 974 25 384
# 398 359
# 576
# 25
# 0 0
# 0 0
# 173
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0034_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0034_Trim.txt
# 0 700 111 864 266
#
# 590 973 7 369
# 383 362
# 590
# 7
# 0 0
# 0 0
# 244
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0035_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0035_Trim.txt
# 0 690 128 862 282
#
# 575 976 25 384
# 401 359
# 575
# 25
# 0 0
# 0 0
# 514
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0036_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0036_Trim.txt
# 0 701 113 865 266
#
# 591 974 11 367
# 383 356
# 591
# 11
# 0 0
# 0 0
# 416
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0037_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0037_Trim.txt
# 0 691 130 862 282
#
# 577 975 28 383
# 398 355
# 577
# 28
# 0 0
# 0 0
# 292
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0038_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0038_Trim.txt
# 0 701 113 865 267
#
# 591 974 10 369
# 383 359
# 591
# 10
# 0 0
# 0 0
# 244
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0039_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0039_Trim.txt
# 0 691 129 855 283
#
# 581 964 26 385
# 383 359
# 581
# 26
# 0 0
# 0 0
# 334
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0040_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0040_Trim.txt
# 0 701 113 865 267
#
# 591 974 10 369
# 383 359
# 591
# 10
# 0 0
# 0 0
# 272
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0041_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0041_Trim.txt
# 0 690 129 859 282
#
# 577 971 27 383
# 394 356
# 577
# 27
# 0 0
# 0 0
# 272
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0042_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0042_Trim.txt
# 0 701 113 864 267
#
# 592 972 10 369
# 380 359
# 592
# 10
# 0 0
# 0 0
# 299
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0043_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0043_Trim.txt
# 0 689 125 862 283
#
# 573 977 19 388
# 404 369
# 573
# 19
# 0 0
# 0 0
# 293
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0044_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0044_Trim.txt
# 0 701 112 864 266
#
# 592 972 9 368
# 380 359
# 592
# 9
# 0 0
# 0 0
# 232
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0045_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0045_Trim.txt
# 0 691 128 862 281
#
# 577 975 26 382
# 398 356
# 577
# 26
# 0 0
# 0 0
# 280
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0046_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0046_Trim.txt
# 0 701 111 863 265
#
# 593 970 8 367
# 377 359
# 593
# 8
# 0 0
# 0 0
# 294
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0048_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0048_Trim.txt
# 0 701 111 863 265
#
# 593 970 8 367
# 377 359
# 593
# 8
# 0 0
# 0 0
# 247
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0049_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0049_Trim.txt
# 0 681 128 864 277
#
# 559 985 28 376
# 426 348
# 559
# 28
# 0 0
# 0 0
# 310
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0050_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0050_Trim.txt
# 0 681 128 864 277
#
# 559 985 28 376
# 426 348
# 559
# 28
# 0 0
# 0 0
# 438
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0051_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0051_Trim.txt
# 0 695 119 857 275
#
# 587 964 15 378
# 377 363
# 587
# 15
# 0 0
# 0 0
# 218
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0052_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0052_Trim.txt
# 0 695 119 857 275
#
# 587 964 15 378
# 377 363
# 587
# 15
# 0 0
# 0 0
# 431
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0053_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0053_Trim.txt
# 0 695 119 857 275
#
# 587 964 15 378
# 377 363
# 587
# 15
# 0 0
# 0 0
# 306
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0054_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0054_Trim.txt
# 0 695 119 857 275
#
# 587 964 15 378
# 377 363
# 587
# 15
# 0 0
# 0 0
# 330
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0055_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0055_Trim.txt
# 0 695 119 857 275
#
# 587 964 15 378
# 377 363
# 587
# 15
# 0 0
# 0 0
# 315
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0056_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0056_Trim.txt
# 0 695 123 857 275
#
# 587 964 21 376
# 377 355
# 587
# 21
# 0 0
# 0 0
# 249
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0057_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0057_Trim.txt
# 0 695 123 857 275
#
# 587 964 21 376
# 377 355
# 587
# 21
# 0 0
# 0 0
# 311
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0058_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0058_Trim.txt
# 0 695 123 857 275
#
# 587 964 21 376
# 377 355
# 587
# 21
# 0 0
# 0 0
# 287
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0059_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0059_Trim.txt
# 0 695 123 857 275
#
# 587 964 21 376
# 377 355
# 587
# 21
# 0 0
# 0 0
# 350
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0060_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0060_Trim.txt
# 0 695 123 857 275
#
# 587 964 21 376
# 377 355
# 587
# 21
# 0 0
# 0 0
# 344
# C:/Users/glad/Desktop/졸업/Trim_data_raw/220510_SS_LS_WE_0061_Trim.mp4
# C:/Users/glad/Desktop/졸업/Trim_data_first_image/220510_SS_LS_WE_0061_Trim.txt
# 0 695 123 857 275
#
# 587 964 21 376
# 377 355
# 587
# 21
# 0 0
# 0 0
# 309
